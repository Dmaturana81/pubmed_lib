# %% [raw]
# ---
# description: Module with some data to be use in the treatment of the data
# output-file: data.html
# title: data
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(get_from_dict_or_env)
# Out:
# ---
#
# [source](https://github.com/Dmaturana81/pubmed_lib/blob/main/pubmed_lib/data.py#L14){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_from_dict_or_env
#
# >      get_from_dict_or_env (data:Dict[str,Any], key:str, env_key:str,
# >                            default:Optional[str]=None)
#
# Get a value from a dictionary or an environment variable.

# %%
#| echo: false
#| output: asis
show_doc(get_from_env)
# Out:
# ---
#
# [source](https://github.com/Dmaturana81/pubmed_lib/blob/main/pubmed_lib/data.py#L24){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_from_env
#
# >      get_from_env (key:str, env_key:str, default:Optional[str]=None)
#
# Get a value from a dictionary or an environment variable.

# %%
#| echo: false
#| output: asis
show_doc(countries2list)
# Out:
# ---
#
# [source](https://github.com/Dmaturana81/pubmed_lib/blob/main/pubmed_lib/data.py#L473){target="_blank" style="float:right; font-size:smaller"}
#
# ### countries2list
#
# >      countries2list (COUNTRIES)

# %%
#| echo: false
#| output: asis
show_doc(lower_countries)
# Out:
# ---
#
# [source](https://github.com/Dmaturana81/pubmed_lib/blob/main/pubmed_lib/data.py#L465){target="_blank" style="float:right; font-size:smaller"}
#
# ### lower_countries
#
# >      lower_countries (COUNTRIES)
