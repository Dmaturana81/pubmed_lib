# %% [raw]
# ---
# description: Functionalities to parse the different information comming from pubmed
#   results
# output-file: parser.html
# title: Parser
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(parsePubmedData)
# Out:
# ---
#
# [source](https://github.com/Dmaturana81/pubmed_lib/blob/main/pubmed_lib/parser.py#L31){target="_blank" style="float:right; font-size:smaller"}
#
# ### parsePubmedData
#
# >      parsePubmedData (pubmeddata:dict)
#
# Receive the xml section of PubmedData and return list of ids
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | pubmeddata | dict | Data retrieve from pubmedData |
# | **Returns** | **list** |  |

# %%
#| echo: false
#| output: asis
show_doc(parseArticle)
# Out:
# ---
#
# [source](https://github.com/Dmaturana81/pubmed_lib/blob/main/pubmed_lib/parser.py#L41){target="_blank" style="float:right; font-size:smaller"}
#
# ### parseArticle
#
# >      parseArticle (article_info:dict)
#
# Function to extract information from an Article, including Title, Abstract, AutorList, journal and published Date
# :param article_info: dictionary from key Article of an Medline citation
# :return (dict): tuple of dictionary with information from paper and autors
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | article_info | dict | Dictionary containing information of the article ('Article' Key) |
# | **Returns** | **dict** | **Somethign** |

# %%
#| echo: false
#| output: asis
show_doc(parse_email)
# Out:
# ---
#
# [source](https://github.com/Dmaturana81/pubmed_lib/blob/main/pubmed_lib/parser.py#L76){target="_blank" style="float:right; font-size:smaller"}
#
# ### parse_email
#
# >      parse_email (affil_text:str)
#
# Find email from the Affiliation text (Maybe use the reg_email regex and not the one in the function, TEST)
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | affil_text | str | Affiliations information for each autor in the Article |
# | **Returns** | **str** |  |

# %%
#| echo: false
#| output: asis
show_doc(parseMayorKeys)
# Out:
# ---
#
# [source](https://github.com/Dmaturana81/pubmed_lib/blob/main/pubmed_lib/parser.py#L91){target="_blank" style="float:right; font-size:smaller"}
#
# ### parseMayorKeys
#
# >      parseMayorKeys (citationInfo:dict)
#
# Function to Parse the Mayor Keys from the Article.
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | citationInfo | dict | Dictionary from 'MedlineCitation' key containing keywords information |
# | **Returns** | **list** |  |

# %%
#| echo: false
#| output: asis
show_doc(parseMeshKeys)
# Out:
# ---
#
# [source](https://github.com/Dmaturana81/pubmed_lib/blob/main/pubmed_lib/parser.py#L103){target="_blank" style="float:right; font-size:smaller"}
#
# ### parseMeshKeys
#
# >      parseMeshKeys (citationInfo:dict)
#
# Function to Parse the Mayor and Minor MeSH Keys from the Article.
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | citationInfo | dict | Dictionary from 'MedlineCitation' key containing keywords information |
# | **Returns** | **(<class 'list'>, <class 'list'>)** |  |

# %%
#| echo: false
#| output: asis
show_doc(parseKeys)
# Out:
# ---
#
# [source](https://github.com/Dmaturana81/pubmed_lib/blob/main/pubmed_lib/parser.py#L114){target="_blank" style="float:right; font-size:smaller"}
#
# ### parseKeys
#
# >      parseKeys (citationInfo:dict)
#
# Function to retrieve the mayor keys as well as MEsh Keys
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | citationInfo | dict | Dictionary from 'MedlineCitation' key containing keywords information |
# | **Returns** | **tuple** |  |

# %%
#| echo: false
#| output: asis
show_doc(parse_paperinfo)
# Out:
# ---
#
# [source](https://github.com/Dmaturana81/pubmed_lib/blob/main/pubmed_lib/parser.py#L123){target="_blank" style="float:right; font-size:smaller"}
#
# ### parse_paperinfo
#
# >      parse_paperinfo (paperinfo_xml:str)
#
# Function that parse the paper inforation and retrieve a dictionary
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | paperinfo_xml | str | Xml data retreived from pubmed |
# | **Returns** | **dict** |  |

# %%
#| echo: false
#| output: asis
show_doc(parse_author_xml)
# Out:
# ---
#
# [source](https://github.com/Dmaturana81/pubmed_lib/blob/main/pubmed_lib/parser.py#L153){target="_blank" style="float:right; font-size:smaller"}
#
# ### parse_author_xml
#
# >      parse_author_xml (autor_xml)
#
# Receive a dictionary from pubmed with the information of the Author. Retreive a Autor object with all the information parsed
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | autor_xml |  | Xml data containing information for each author |
# | **Returns** | **Autor** |  |

# %%
#| echo: false
#| output: asis
show_doc(parse_affiliation)
# Out:
# ---
#
# [source](https://github.com/Dmaturana81/pubmed_lib/blob/main/pubmed_lib/parser.py#L206){target="_blank" style="float:right; font-size:smaller"}
#
# ### parse_affiliation
#
# >      parse_affiliation (aff:str, LLM:bool=False)
#
# Function that direct the parsing of the affiliation

# %%
from pubmed_lib.search import Search


search = Search(search_tag='Author', retmax=2)
res = search.results('Andreas Langer')
res
# Out:
# Results(results=[Result(pubmed='35171002', pmc='PMC8968852', doi='10.1089/adt.2021.133', pii=None, abstract='There are many fluorescence-based applications that can be used to characterize molecular interactions. However, available methods often depend on site-specific labeling techniques or binding-induced changes in conformation or size of the probed target molecule. To overcome these limitations, we applied a ratiometric dual-emission approach that quantifies ligand-induced spectral shifts with sub-nanometer sensitivity. The use of environment-sensitive near-infrared dyes with the method we describe enables affinity measurements and thermodynamic characterization without the explicit need for site-specific labeling or ligand-induced conformational changes. We demonstrate that in-solution spectral shift measurements enable precise characterization of molecular interactions for a variety of biomolecules, including proteins, antibodies, and nucleic acids. Thereby, the described metho
# ...

# %%
res.to_df('autors')
# Out:
#     index    pubmed         pmc                          doi  \
# 0       0  35171002  PMC8968852         10.1089/adt.2021.133
# 1       0  35171002  PMC8968852         10.1089/adt.2021.133
# 2       0  35171002  PMC8968852         10.1089/adt.2021.133
# 3       0  35171002  PMC8968852         10.1089/adt.2021.133
# 4       0  35171002  PMC8968852         10.1089/adt.2021.133
# 5       0  35171002  PMC8968852         10.1089/adt.2021.133
# 6       1  28286323        None  10.1016/j.ymeth.2017.03.004
# 7       1  28286323        None  10.1016/j.ymeth.2017.03.004
# 8       1  28286323        None  10.1016/j.ymeth.2017.03.004
# 9       1  28286323        None  10.1016/j.ymeth.2017.03.004
# 10      1  28286323        None  10.1016/j.ymeth.2017.03.004
#
#                       pii                                           abstract  \
# 0                    None  There are many fluorescence-based applications...
# ...

# %%
parse_affil("Department of Health Science, Kochi Women's University, Kochi 780-8515, Japan. watanabe@cc.kochi-wu.ac.jp")
# Out:
# ...
# {'full_text': "Department of Health Science, Kochi Women's University, Kochi , Japan.",
#  'department': 'Department of Health Science',
#  'institution': "Kochi Women's University",
#  'email': 'watanabe@cc.kochi-wu.ac.jp',
#  'zipcode': '780-8515',
#  'location': 'Kochi , Japan',
#  'country': 'japan'}
