# %% [raw]
# ---
# description: Result class and all methods to get details and process the publications
# output-file: result.html
# title: result
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# # Fetching some results from search. Should change to a class soon

# %%
class Result(BaseModel):
    """
    Model for results, including all the data taht will be retreived and their type
    """
    pubmed:str
    pmc: str | None = None
    doi: str | None = None
    pii: str | None = None
    abstract: str
    autorlist: List[Autor]
    title: str
    journal: str
    published: date | None = None 
    mayorKeys: List[str]
    mayorMesh: List[str]
    minorMesh: List[str]

# %%
#| echo: false
#| output: asis
show_doc(Result)
# Out:
# ---
#
# [source](https://github.com/Dmaturana81/pubmed_lib/blob/main/pubmed_lib/result.py#L20){target="_blank" style="float:right; font-size:smaller"}
#
# ### Result
#
# >      Result (pubmed:str, pmc:str|None=None, doi:str|None=None,
# >              pii:str|None=None, abstract:str,
# >              autorlist:List[pubmed_lib.author.Autor], title:str, journal:str,
# >              published:datetime.date|None=None, mayorKeys:List[str],
# >              mayorMesh:List[str], minorMesh:List[str])
#
# Model for results, including all the data taht will be retreived and their type

# %% [markdown]
# # Class for list of [`Result`](https://Dmaturana81.github.io/pubmed_lib/result.html#result) and its methods

# %%
class Results(BaseModel):
    """Class to store a list of `Result`"""
    results: List[Result] =[]

# %%
#| echo: false
#| output: asis
show_doc(Results)
# Out:
# ---
#
# [source](https://github.com/Dmaturana81/pubmed_lib/blob/main/pubmed_lib/result.py#L60){target="_blank" style="float:right; font-size:smaller"}
#
# ### Results
#
# >      Results (results:List[__main__.Result]=[])
#
# Class to store a list of `Result`

# %%
#| echo: false
#| output: asis
show_doc(Results.append)
# Out:
# ---
#
# [source](https://github.com/Dmaturana81/pubmed_lib/blob/main/pubmed_lib/result.py#L66){target="_blank" style="float:right; font-size:smaller"}
#
# ### Results.append
#
# >      Results.append (item:__main__.Result)
#
# Method to add item on the list of result

# %%
#| echo: false
#| output: asis
show_doc(Results.to_df)
# Out:
# ---
#
# [source](https://github.com/Dmaturana81/pubmed_lib/blob/main/pubmed_lib/result.py#L83){target="_blank" style="float:right; font-size:smaller"}
#
# ### Results.to_df
#
# >      Results.to_df (mode:str='publication')
#
# Method to add item on the list of result
