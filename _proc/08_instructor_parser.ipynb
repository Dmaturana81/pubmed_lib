# %% [raw]
# ---
# description: Using OpenAI and instructor to parse the affiliation information
# output-file: instructor_parser.html
# title: InstructorParser
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(Affiliation)
# Out:
# ---
#
# [source](https://github.com/Dmaturana81/pubmed_lib/blob/main/pubmed_lib/instructor_parser.py#L15){target="_blank" style="float:right; font-size:smaller"}
#
# ### Affiliation
#
# >      Affiliation (organization:str='', laboratory:str='', department:str='',
# >                   faculty:str='', country:str='', city:str='', state:str='',
# >                   email:pydantic.networks.EmailStr|None=None)
#
# Affiliation data representation

# %%
#| echo: false
#| output: asis
show_doc(InstructorParser)
# Out:
# ---
#
# [source](https://github.com/Dmaturana81/pubmed_lib/blob/main/pubmed_lib/instructor_parser.py#L52){target="_blank" style="float:right; font-size:smaller"}
#
# ### InstructorParser
#
# >      InstructorParser (data_class:Any, model:str='gpt-4-1106-preview')
#
# Class to activate the OpenAI Parser algorithm
